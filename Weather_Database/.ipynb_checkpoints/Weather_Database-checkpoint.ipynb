# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1])
    
    # If the city is unique, then add it to a our cities list
    if city.city_name not in cities:
        cities.append(city.city_name)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 761

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
# The sample output appears to use imperial units, so this is used here.
url = 'https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=' + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # lon, lat dict ('coord') will start the data dictionary, and the rest of the items will be appended
        data_dict = city_weather['coord']
        data_dict['Max Temp'] = city_weather['main']['temp_max']
        data_dict['Humidity'] = city_weather['main']['humidity']
        data_dict['Cloudiness'] = city_weather['clouds']['all']
        data_dict['Wind Speed'] = city_weather['wind']['speed']
        data_dict['Country'] = city_weather['sys']['country']
        data_dict['Current Description'] = city_weather['weather'][0]['description']
        # Add city name in normal capitalized format
        data_dict['City'] = city.title()


        # Append the city information into the city_data list
        city_data.append(data_dict)
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(city_data[0:5])
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | gat
# Processing Record 3 of Set 1 | elko
# Processing Record 4 of Set 1 | vanavara
# Processing Record 5 of Set 1 | westport
# Processing Record 6 of Set 1 | kaeo
# Processing Record 7 of Set 1 | alihe
# Processing Record 8 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | talnakh
# Processing Record 12 of Set 1 | morant bay
# Processing Record 13 of Set 1 | zanatepec
# City not found. Skipping...
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | saint-augustin
# Processing Record 19 of Set 1 | leningradskiy
# Processing Record 20 of Set 1 | phan thiet
# Processing Record 21 of Set 1 | banda aceh
# Processing Record 22 of Set 1 | faya
# Processing Record 23 of Set 1 | laguna
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | namibe
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 1 | iquitos
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | bambanglipuro
# Processing Record 35 of Set 1 | biak
# Processing Record 36 of Set 1 | vostok
# Processing Record 37 of Set 1 | jiancheng
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | kismayo
# Processing Record 41 of Set 1 | nishihara
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | arlit
# Processing Record 45 of Set 1 | galveston
# Processing Record 46 of Set 1 | severnyy
# Processing Record 47 of Set 1 | sanmenxia
# Processing Record 48 of Set 1 | weatherford
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | vao
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | kazerun
# Processing Record 4 of Set 2 | kotelnich
# Processing Record 5 of Set 2 | muros
# Processing Record 6 of Set 2 | rocha
# Processing Record 7 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 2 | biscarrosse
# Processing Record 9 of Set 2 | okhotsk
# Processing Record 10 of Set 2 | farah
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 2 | codrington
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | monduli
# Processing Record 16 of Set 2 | barela
# Processing Record 17 of Set 2 | hay river
# Processing Record 18 of Set 2 | zhigansk
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | tahta
# Processing Record 21 of Set 2 | tubuala
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | santiago del estero
# Processing Record 25 of Set 2 | butembo
# Processing Record 26 of Set 2 | trairi
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | kaitangata
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | bluff
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | kommunisticheskiy
# Processing Record 35 of Set 2 | mitsamiouli
# Processing Record 36 of Set 2 | isangel
# Processing Record 37 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 2 | mayskiy
# Processing Record 39 of Set 2 | san cristobal
# Processing Record 40 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 2 | forio
# Processing Record 43 of Set 2 | solnechnyy
# Processing Record 44 of Set 2 | sao geraldo do araguaia
# Processing Record 45 of Set 2 | nikolskoye
# Processing Record 46 of Set 2 | qaqortoq
# Processing Record 47 of Set 2 | adrar
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | pauini
# Processing Record 1 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 3 | zyryanka
# Processing Record 3 of Set 3 | sorland
# Processing Record 4 of Set 3 | tshikapa
# Processing Record 5 of Set 3 | tadine
# Processing Record 6 of Set 3 | stolin
# Processing Record 7 of Set 3 | san marcos
# Processing Record 8 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | kutum
# Processing Record 11 of Set 3 | jinchang
# Processing Record 12 of Set 3 | minot
# Processing Record 13 of Set 3 | wewak
# Processing Record 14 of Set 3 | vila velha
# Processing Record 15 of Set 3 | ayagoz
# Processing Record 16 of Set 3 | severnoye
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | fortuna
# Processing Record 20 of Set 3 | arinos
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | lorengau
# Processing Record 23 of Set 3 | zaozerne
# Processing Record 24 of Set 3 | kenai
# Processing Record 25 of Set 3 | pujehun
# Processing Record 26 of Set 3 | goderich
# Processing Record 27 of Set 3 | san joaquin
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | nsanje
# Processing Record 30 of Set 3 | bilibino
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | chegdomyn
# Processing Record 33 of Set 3 | esperance
# Processing Record 34 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | assiniboia
# Processing Record 37 of Set 3 | kavieng
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | aripuana
# Processing Record 40 of Set 3 | batagay-alyta
# Processing Record 41 of Set 3 | nanyang
# Processing Record 42 of Set 3 | noumea
# Processing Record 43 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 3 | amurzet
# Processing Record 45 of Set 3 | nantucket
# Processing Record 46 of Set 3 | cayenne
# Processing Record 47 of Set 3 | lejanias
# Processing Record 48 of Set 3 | poya
# Processing Record 49 of Set 3 | nemuro
# Processing Record 50 of Set 3 | mareeba
# Processing Record 1 of Set 4 | huntsville
# Processing Record 2 of Set 4 | palmer
# Processing Record 3 of Set 4 | aasiaat
# Processing Record 4 of Set 4 | puerto carreno
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | khovu-aksy
# Processing Record 7 of Set 4 | mnogovershinnyy
# Processing Record 8 of Set 4 | wexford
# Processing Record 9 of Set 4 | simao
# Processing Record 10 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | mahebourg
# Processing Record 13 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 14 of Set 4 | pevek
# Processing Record 15 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 4 | zimapan
# Processing Record 17 of Set 4 | cartagena
# Processing Record 18 of Set 4 | pitimbu
# Processing Record 19 of Set 4 | bereda
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | airai
# Processing Record 22 of Set 4 | katsuura
# Processing Record 23 of Set 4 | kapit
# Processing Record 24 of Set 4 | bull savanna
# Processing Record 25 of Set 4 | khatanga
# Processing Record 26 of Set 4 | georgetown
# Processing Record 27 of Set 4 | norman wells
# Processing Record 28 of Set 4 | butaritari
# Processing Record 29 of Set 4 | porangatu
# Processing Record 30 of Set 4 | samarinda
# Processing Record 31 of Set 4 | new norfolk
# Processing Record 32 of Set 4 | tuyen quang
# Processing Record 33 of Set 4 | griffith
# Processing Record 34 of Set 4 | lasa
# Processing Record 35 of Set 4 | portland
# Processing Record 36 of Set 4 | fuyang
# Processing Record 37 of Set 4 | panguna
# Processing Record 38 of Set 4 | tual
# Processing Record 39 of Set 4 | carnarvon
# Processing Record 40 of Set 4 | kruisfontein
# Processing Record 41 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 42 of Set 4 | myitkyina
# Processing Record 43 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 4 | torbay
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | predivinsk
# Processing Record 47 of Set 4 | aguimes
# Processing Record 48 of Set 4 | salalah
# Processing Record 49 of Set 4 | vila franca do campo
# Processing Record 50 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 5 | grand gaube
# Processing Record 2 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 3 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 5 | povenets
# Processing Record 5 of Set 5 | avarua
# Processing Record 6 of Set 5 | verkhnevilyuysk
# Processing Record 7 of Set 5 | farmington
# Processing Record 8 of Set 5 | mosquera
# Processing Record 9 of Set 5 | khash
# Processing Record 10 of Set 5 | cherskiy
# Processing Record 11 of Set 5 | kasempa
# Processing Record 12 of Set 5 | margate
# Processing Record 13 of Set 5 | vanimo
# Processing Record 14 of Set 5 | shimoda
# Processing Record 15 of Set 5 | srandakan
# Processing Record 16 of Set 5 | saldanha
# Processing Record 17 of Set 5 | bairiki
# Processing Record 18 of Set 5 | east london
# Processing Record 19 of Set 5 | chapais
# Processing Record 20 of Set 5 | ust-tsilma
# Processing Record 21 of Set 5 | tuktoyaktuk
# Processing Record 22 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 5 | hue
# Processing Record 24 of Set 5 | luebo
# Processing Record 25 of Set 5 | lincoln
# Processing Record 26 of Set 5 | banjar
# Processing Record 27 of Set 5 | nanortalik
# Processing Record 28 of Set 5 | hilo
# Processing Record 29 of Set 5 | port lincoln
# Processing Record 30 of Set 5 | osypenko
# Processing Record 31 of Set 5 | khandbari
# Processing Record 32 of Set 5 | dabakala
# Processing Record 33 of Set 5 | te anau
# Processing Record 34 of Set 5 | san quintin
# Processing Record 35 of Set 5 | ukiah
# Processing Record 36 of Set 5 | san patricio
# Processing Record 37 of Set 5 | ponta do sol
# Processing Record 38 of Set 5 | tevaitoa
# Processing Record 39 of Set 5 | pangnirtung
# Processing Record 40 of Set 5 | pechora
# Processing Record 41 of Set 5 | araguacu
# Processing Record 42 of Set 5 | suntar
# Processing Record 43 of Set 5 | livani
# Processing Record 44 of Set 5 | soderhamn
# Processing Record 45 of Set 5 | quatre cocos
# Processing Record 46 of Set 5 | pacific grove
# Processing Record 47 of Set 5 | voi
# Processing Record 48 of Set 5 | fort payne
# Processing Record 49 of Set 5 | garissa
# Processing Record 50 of Set 5 | smidovich
# Processing Record 1 of Set 6 | tiruvottiyur
# City not found. Skipping...
# Processing Record 2 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 6 | najran
# Processing Record 4 of Set 6 | andros town
# Processing Record 5 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 6 | kununurra
# Processing Record 7 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 8 of Set 6 | deputatskiy
# Processing Record 9 of Set 6 | kralendijk
# Processing Record 10 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 6 | port blair
# Processing Record 12 of Set 6 | atambua
# Processing Record 13 of Set 6 | katobu
# Processing Record 14 of Set 6 | hami
# Processing Record 15 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 6 | brae
# Processing Record 17 of Set 6 | tres arroyos
# Processing Record 18 of Set 6 | san ignacio
# Processing Record 19 of Set 6 | autazes
# Processing Record 20 of Set 6 | yellowknife
# Processing Record 21 of Set 6 | tahoua
# Processing Record 22 of Set 6 | yulara
# Processing Record 23 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 6 | lavrentiya
# Processing Record 25 of Set 6 | dauriya
# Processing Record 26 of Set 6 | barabinsk
# Processing Record 27 of Set 6 | puerto del rosario
# Processing Record 28 of Set 6 | leh
# Processing Record 29 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 6 | yenagoa
# Processing Record 31 of Set 6 | marsh harbour
# Processing Record 32 of Set 6 | svetlogorsk
# Processing Record 33 of Set 6 | marzuq
# Processing Record 34 of Set 6 | masvingo
# Processing Record 35 of Set 6 | yanam
# Processing Record 36 of Set 6 | inuvik
# Processing Record 37 of Set 6 | mayumba
# Processing Record 38 of Set 6 | klaksvik
# Processing Record 39 of Set 6 | prince rupert
# Processing Record 40 of Set 6 | saint-georges
# Processing Record 41 of Set 6 | santa maria do suacui
# Processing Record 42 of Set 6 | moose factory
# Processing Record 43 of Set 6 | luderitz
# Processing Record 44 of Set 6 | rincon de la victoria
# Processing Record 45 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 46 of Set 6 | asau
# Processing Record 47 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 48 of Set 6 | nanga eboko
# Processing Record 49 of Set 6 | aleksandrov gay
# Processing Record 50 of Set 6 | olafsvik
# Processing Record 1 of Set 7 | coquimbo
# Processing Record 2 of Set 7 | pozo colorado
# Processing Record 3 of Set 7 | kyren
# Processing Record 4 of Set 7 | sorsk
# Processing Record 5 of Set 7 | ixtapa
# Processing Record 6 of Set 7 | birao
# Processing Record 7 of Set 7 | sterling
# Processing Record 8 of Set 7 | hovd
# Processing Record 9 of Set 7 | dali
# Processing Record 10 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 7 | sampit
# Processing Record 12 of Set 7 | mehamn
# Processing Record 13 of Set 7 | hunucma
# Processing Record 14 of Set 7 | ketchikan
# Processing Record 15 of Set 7 | kaliyaganj
# Processing Record 16 of Set 7 | hornepayne
# Processing Record 17 of Set 7 | palmeiras de goias
# Processing Record 18 of Set 7 | drogheda
# Processing Record 19 of Set 7 | porto novo
# Processing Record 20 of Set 7 | waingapu
# Processing Record 21 of Set 7 | yeniseysk
# Processing Record 22 of Set 7 | maragogi
# Processing Record 23 of Set 7 | blackwater
# Processing Record 24 of Set 7 | usogorsk
# Processing Record 25 of Set 7 | saint-francois
# Processing Record 26 of Set 7 | lagoa
# Processing Record 27 of Set 7 | verkhoyansk
# Processing Record 28 of Set 7 | alyangula
# Processing Record 29 of Set 7 | kutahya
# Processing Record 30 of Set 7 | privolzhsk
# Processing Record 31 of Set 7 | geraldton
# Processing Record 32 of Set 7 | kuching
# Processing Record 33 of Set 7 | linxia
# Processing Record 34 of Set 7 | college
# Processing Record 35 of Set 7 | cabo san lucas
# Processing Record 36 of Set 7 | nenagh
# Processing Record 37 of Set 7 | cidreira
# Processing Record 38 of Set 7 | northam
# Processing Record 39 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 7 | shingu
# Processing Record 41 of Set 7 | samarai
# Processing Record 42 of Set 7 | ciudad guayana
# Processing Record 43 of Set 7 | comodoro rivadavia
# Processing Record 44 of Set 7 | berdigestyakh
# Processing Record 45 of Set 7 | radhanpur
# Processing Record 46 of Set 7 | kattivakkam
# Processing Record 47 of Set 7 | sitka
# Processing Record 48 of Set 7 | steamboat springs
# Processing Record 49 of Set 7 | gorom-gorom
# Processing Record 50 of Set 7 | yumen
# Processing Record 1 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 2 of Set 8 | wanaka
# Processing Record 3 of Set 8 | yerofey pavlovich
# Processing Record 4 of Set 8 | kahului
# Processing Record 5 of Set 8 | saint-pierre
# Processing Record 6 of Set 8 | suez
# Processing Record 7 of Set 8 | bengkulu
# Processing Record 8 of Set 8 | inta
# Processing Record 9 of Set 8 | sola
# Processing Record 10 of Set 8 | bethel
# Processing Record 11 of Set 8 | kozulka
# Processing Record 12 of Set 8 | korla
# Processing Record 13 of Set 8 | los llanos de aridane
# Processing Record 14 of Set 8 | bonthe
# Processing Record 15 of Set 8 | ferrol
# Processing Record 16 of Set 8 | silifke
# Processing Record 17 of Set 8 | katsina
# Processing Record 18 of Set 8 | maningrida
# Processing Record 19 of Set 8 | tilichiki
# Processing Record 20 of Set 8 | alice springs
# Processing Record 21 of Set 8 | krasnoselkup
# Processing Record 22 of Set 8 | vadso
# Processing Record 23 of Set 8 | pringsewu
# Processing Record 24 of Set 8 | teixoso
# Processing Record 25 of Set 8 | san rafael del sur
# Processing Record 26 of Set 8 | santa rosalia
# Processing Record 27 of Set 8 | yuanping
# Processing Record 28 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 8 | hasaki
# Processing Record 30 of Set 8 | saint-joseph
# Processing Record 31 of Set 8 | mogadishu
# Processing Record 32 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 8 | bandarbeyla
# Processing Record 34 of Set 8 | sabang
# Processing Record 35 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 8 | marawi
# Processing Record 37 of Set 8 | tessalit
# Processing Record 38 of Set 8 | camacha
# Processing Record 39 of Set 8 | lompoc
# Processing Record 40 of Set 8 | san luis de la paz
# Processing Record 41 of Set 8 | dolores
# Processing Record 42 of Set 8 | khandyga
# Processing Record 43 of Set 8 | kapoeta
# Processing Record 44 of Set 8 | san carlos
# Processing Record 45 of Set 8 | svetlaya
# Processing Record 46 of Set 8 | muroto
# Processing Record 47 of Set 8 | elizabeth city
# Processing Record 48 of Set 8 | nouakchott
# Processing Record 49 of Set 8 | orsha
# Processing Record 50 of Set 8 | kabompo
# Processing Record 1 of Set 9 | hamilton
# Processing Record 2 of Set 9 | yerbogachen
# Processing Record 3 of Set 9 | kungsbacka
# Processing Record 4 of Set 9 | iskateley
# Processing Record 5 of Set 9 | palimbang
# Processing Record 6 of Set 9 | padang
# Processing Record 7 of Set 9 | tura
# Processing Record 8 of Set 9 | nabire
# Processing Record 9 of Set 9 | cobadin
# Processing Record 10 of Set 9 | avera
# Processing Record 11 of Set 9 | roald
# Processing Record 12 of Set 9 | vestmanna
# Processing Record 13 of Set 9 | darhan
# Processing Record 14 of Set 9 | diapaga
# Processing Record 15 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 9 | whitecourt
# Processing Record 17 of Set 9 | sept-iles
# Processing Record 18 of Set 9 | maceio
# Processing Record 19 of Set 9 | copiapo
# Processing Record 20 of Set 9 | kisangani
# Processing Record 21 of Set 9 | maromitsa
# Processing Record 22 of Set 9 | havre-saint-pierre
# Processing Record 23 of Set 9 | kargopol
# Processing Record 24 of Set 9 | igarape-miri
# City not found. Skipping...
# Processing Record 25 of Set 9 | stephenville
# Processing Record 26 of Set 9 | ndende
# Processing Record 27 of Set 9 | itarema
# Processing Record 28 of Set 9 | raton
# Processing Record 29 of Set 9 | soyo
# Processing Record 30 of Set 9 | karratha
# Processing Record 31 of Set 9 | pandaria
# Processing Record 32 of Set 9 | touros
# Processing Record 33 of Set 9 | corinto
# Processing Record 34 of Set 9 | nampula
# Processing Record 35 of Set 9 | kabin buri
# Processing Record 36 of Set 9 | narsaq
# Processing Record 37 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 38 of Set 9 | pundaguitan
# Processing Record 39 of Set 9 | winslow
# Processing Record 40 of Set 9 | west odessa
# Processing Record 41 of Set 9 | bandiagara
# Processing Record 42 of Set 9 | dhidhdhoo
# Processing Record 43 of Set 9 | salekhard
# Processing Record 44 of Set 9 | marysville
# Processing Record 45 of Set 9 | ostersund
# Processing Record 46 of Set 9 | dalbandin
# Processing Record 47 of Set 9 | quang ngai
# Processing Record 48 of Set 9 | half moon bay
# Processing Record 49 of Set 9 | kanker
# Processing Record 50 of Set 9 | aktau
# Processing Record 1 of Set 10 | marsa matruh
# Processing Record 2 of Set 10 | whitehorse
# Processing Record 3 of Set 10 | atar
# Processing Record 4 of Set 10 | pachino
# Processing Record 5 of Set 10 | houma
# Processing Record 6 of Set 10 | vardo
# Processing Record 7 of Set 10 | erenhot
# Processing Record 8 of Set 10 | acapulco
# Processing Record 9 of Set 10 | namatanai
# Processing Record 10 of Set 10 | castle rock
# Processing Record 11 of Set 10 | naze
# Processing Record 12 of Set 10 | vallenar
# Processing Record 13 of Set 10 | hambantota
# Processing Record 14 of Set 10 | galeana
# Processing Record 15 of Set 10 | kalomo
# City not found. Skipping...
# Processing Record 16 of Set 10 | weligama
# Processing Record 17 of Set 10 | mount gambier
# Processing Record 18 of Set 10 | komsomolskiy
# Processing Record 19 of Set 10 | cocobeach
# Processing Record 20 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 10 | saint george
# Processing Record 22 of Set 10 | manokwari
# Processing Record 23 of Set 10 | bubaque
# Processing Record 24 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 25 of Set 10 | siparia
# Processing Record 26 of Set 10 | poyarkovo
# Processing Record 27 of Set 10 | berlevag
# Processing Record 28 of Set 10 | jiuquan
# Processing Record 29 of Set 10 | cerrito
# Processing Record 30 of Set 10 | wenling
# Processing Record 31 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 10 | evensk
# Processing Record 33 of Set 10 | graaff-reinet
# Processing Record 34 of Set 10 | cabedelo
# Processing Record 35 of Set 10 | itaituba
# Processing Record 36 of Set 10 | charters towers
# Processing Record 37 of Set 10 | balabac
# Processing Record 38 of Set 10 | nicoya
# Processing Record 39 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 10 | podyuga
# Processing Record 41 of Set 10 | dubbo
# Processing Record 42 of Set 10 | puerto baquerizo moreno
# Processing Record 43 of Set 10 | bocanda
# Processing Record 44 of Set 10 | ancud
# Processing Record 45 of Set 10 | moyale
# Processing Record 46 of Set 10 | mount isa
# Processing Record 47 of Set 10 | aklavik
# Processing Record 48 of Set 10 | sur
# Processing Record 49 of Set 10 | sembe
# Processing Record 50 of Set 10 | khuzdar
# Processing Record 1 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 11 | constitucion
# Processing Record 3 of Set 11 | ranong
# Processing Record 4 of Set 11 | hirara
# Processing Record 5 of Set 11 | vilhena
# Processing Record 6 of Set 11 | verkhnetulomskiy
# Processing Record 7 of Set 11 | sharkan
# Processing Record 8 of Set 11 | mandalgovi
# Processing Record 9 of Set 11 | puerto escondido
# Processing Record 10 of Set 11 | guadalupe y calvo
# Processing Record 11 of Set 11 | gamba
# Processing Record 12 of Set 11 | el badari
# City not found. Skipping...
# Processing Record 13 of Set 11 | poitiers
# Processing Record 14 of Set 11 | santa isabel do rio negro
# Processing Record 15 of Set 11 | ankpa
# Processing Record 16 of Set 11 | victor harbor
# Processing Record 17 of Set 11 | dhari
# Processing Record 18 of Set 11 | nkayi
# Processing Record 19 of Set 11 | lapua
# Processing Record 20 of Set 11 | altamirano
# Processing Record 21 of Set 11 | mukhtolovo
# Processing Record 22 of Set 11 | berbera
# Processing Record 23 of Set 11 | poum
# Processing Record 24 of Set 11 | hit
# Processing Record 25 of Set 11 | taoudenni
# Processing Record 26 of Set 11 | puerto leguizamo
# Processing Record 27 of Set 11 | reporoa
# Processing Record 28 of Set 11 | lebyazhye
# Processing Record 29 of Set 11 | malakal
# Processing Record 30 of Set 11 | jibuti
# Processing Record 31 of Set 11 | meulaboh
# Processing Record 32 of Set 11 | coihaique
# Processing Record 33 of Set 11 | methoni
# Processing Record 34 of Set 11 | agadez
# Processing Record 35 of Set 11 | say
# Processing Record 36 of Set 11 | noshiro
# Processing Record 37 of Set 11 | baft
# Processing Record 38 of Set 11 | lampang
# Processing Record 39 of Set 11 | tymovskoye
# Processing Record 40 of Set 11 | milyutinskaya
# Processing Record 41 of Set 11 | hofn
# Processing Record 42 of Set 11 | tuatapere
# Processing Record 43 of Set 11 | ahipara
# Processing Record 44 of Set 11 | tigil
# Processing Record 45 of Set 11 | price
# Processing Record 46 of Set 11 | gobabis
# Processing Record 47 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 11 | zambezi
# Processing Record 49 of Set 11 | makakilo city
# Processing Record 50 of Set 11 | akhmim
# Processing Record 1 of Set 12 | rincon
# Processing Record 2 of Set 12 | antsohihy
# Processing Record 3 of Set 12 | bobcaygeon
# Processing Record 4 of Set 12 | chuy
# Processing Record 5 of Set 12 | longyearbyen
# Processing Record 6 of Set 12 | aykhal
# Processing Record 7 of Set 12 | castelo do piaui
# Processing Record 8 of Set 12 | beaufort
# Processing Record 9 of Set 12 | merauke
# Processing Record 10 of Set 12 | harper
# Processing Record 11 of Set 12 | umm lajj
# Processing Record 12 of Set 12 | alekseyevsk
# Processing Record 13 of Set 12 | menongue
# Processing Record 14 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 15 of Set 12 | omsukchan
# Processing Record 16 of Set 12 | ladario
# Processing Record 17 of Set 12 | vuktyl
# Processing Record 18 of Set 12 | imbituba
# Processing Record 19 of Set 12 | sault sainte marie
# Processing Record 20 of Set 12 | broome
# Processing Record 21 of Set 12 | radom
# Processing Record 22 of Set 12 | khor
# Processing Record 23 of Set 12 | srednekolymsk
# Processing Record 24 of Set 12 | jacareacanga
# Processing Record 25 of Set 12 | cap-aux-meules
# Processing Record 26 of Set 12 | rio hato
# Processing Record 27 of Set 12 | sumter
# Processing Record 28 of Set 12 | luxor
# Processing Record 29 of Set 12 | skjervoy
# Processing Record 30 of Set 12 | north bend
# Processing Record 31 of Set 12 | sigli
# Processing Record 32 of Set 12 | bhinmal
# Processing Record 33 of Set 12 | stornoway
# Processing Record 34 of Set 12 | dingle
# Processing Record 35 of Set 12 | araguari
# Processing Record 36 of Set 12 | severo-yeniseyskiy
# Processing Record 37 of Set 12 | dasoguz
# Processing Record 38 of Set 12 | juba
# Processing Record 39 of Set 12 | arco
# Processing Record 40 of Set 12 | port hardy
# Processing Record 41 of Set 12 | oktyabrskiy
# Processing Record 42 of Set 12 | egvekinot
# Processing Record 43 of Set 12 | dalen
# Processing Record 44 of Set 12 | kloulklubed
# Processing Record 45 of Set 12 | bernalillo
# Processing Record 46 of Set 12 | uruzgan
# Processing Record 47 of Set 12 | camopi
# Processing Record 48 of Set 12 | qui nhon
# Processing Record 49 of Set 12 | okha
# Processing Record 50 of Set 12 | byron bay
# Processing Record 1 of Set 13 | sassandra
# Processing Record 2 of Set 13 | canberra
# Processing Record 3 of Set 13 | husavik
# Processing Record 4 of Set 13 | ust-kuyga
# Processing Record 5 of Set 13 | zabaykalsk
# Processing Record 6 of Set 13 | mackay
# Processing Record 7 of Set 13 | novobirilyussy
# Processing Record 8 of Set 13 | penzance
# Processing Record 9 of Set 13 | xam nua
# Processing Record 10 of Set 13 | bhikangaon
# Processing Record 11 of Set 13 | manzil salim
# Processing Record 12 of Set 13 | iqaluit
# Processing Record 13 of Set 13 | garowe
# Processing Record 14 of Set 13 | maniitsoq
# Processing Record 15 of Set 13 | jhanjharpur
# Processing Record 16 of Set 13 | baykit
# Processing Record 17 of Set 13 | hobyo
# Processing Record 18 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 19 of Set 13 | kasongo-lunda
# Processing Record 20 of Set 13 | skegness
# Processing Record 21 of Set 13 | ewo
# Processing Record 22 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 23 of Set 13 | senno
# Processing Record 24 of Set 13 | zaranj
# Processing Record 25 of Set 13 | mamallapuram
# Processing Record 26 of Set 13 | baghdad
# Processing Record 27 of Set 13 | zalantun
# Processing Record 28 of Set 13 | bima
# Processing Record 29 of Set 13 | manicaragua
# Processing Record 30 of Set 13 | souillac
# Processing Record 31 of Set 13 | synya
# Processing Record 32 of Set 13 | fort nelson
# Processing Record 33 of Set 13 | port-gentil
# Processing Record 34 of Set 13 | iquique
# Processing Record 35 of Set 13 | lohja
# Processing Record 36 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 37 of Set 13 | beringovskiy
# Processing Record 38 of Set 13 | cap-haitien
# Processing Record 39 of Set 13 | tecolutla
# Processing Record 40 of Set 13 | kavaratti
# Processing Record 41 of Set 13 | bathsheba
# Processing Record 42 of Set 13 | morgan city
# Processing Record 43 of Set 13 | mago
# Processing Record 44 of Set 13 | garbolovo
# Processing Record 45 of Set 13 | edd
# Processing Record 46 of Set 13 | wanning
# Processing Record 47 of Set 13 | nokaneng
# Processing Record 48 of Set 13 | la ronge
# Processing Record 49 of Set 13 | chiredzi
# Processing Record 50 of Set 13 | kindu
# Processing Record 1 of Set 14 | tabuk
# Processing Record 2 of Set 14 | karatau
# Processing Record 3 of Set 14 | kupang
# Processing Record 4 of Set 14 | ritchie
# Processing Record 5 of Set 14 | konstantinovka
# Processing Record 6 of Set 14 | nuevitas
# Processing Record 7 of Set 14 | evanston
# Processing Record 8 of Set 14 | ostrovnoy
# Processing Record 9 of Set 14 | mercedes
# Processing Record 10 of Set 14 | nago
# Processing Record 11 of Set 14 | kabare
# Processing Record 12 of Set 14 | mayo
# Processing Record 13 of Set 14 | dandong
# Processing Record 14 of Set 14 | newport
# Processing Record 15 of Set 14 | takoradi
# Processing Record 16 of Set 14 | bonavista
# Processing Record 17 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 14 | san rafael
# Processing Record 19 of Set 14 | makueni
# Processing Record 20 of Set 14 | cerritos
# Processing Record 21 of Set 14 | angoche
# Processing Record 22 of Set 14 | dezful
# Processing Record 23 of Set 14 | rabo de peixe
# Processing Record 24 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 14 | fuerte olimpo
# Processing Record 26 of Set 14 | sao paulo de olivenca
# Processing Record 27 of Set 14 | queanbeyan
# Processing Record 28 of Set 14 | billings
# Processing Record 29 of Set 14 | sao joao da barra
# Processing Record 30 of Set 14 | aktash
# Processing Record 31 of Set 14 | lewiston
# Processing Record 32 of Set 14 | mana
# Processing Record 33 of Set 14 | hwange
# Processing Record 34 of Set 14 | chimbote
# Processing Record 35 of Set 14 | sobolevo
# Processing Record 36 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 37 of Set 14 | nouadhibou
# Processing Record 38 of Set 14 | hajnowka
# Processing Record 39 of Set 14 | tabat
# Processing Record 40 of Set 14 | wadi maliz
# Processing Record 41 of Set 14 | santo tomas
# Processing Record 42 of Set 14 | kyra
# Processing Record 43 of Set 14 | lata
# Processing Record 44 of Set 14 | tecoanapa
# Processing Record 45 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 14 | zhuhai
# Processing Record 47 of Set 14 | kedrovyy
# Processing Record 48 of Set 14 | jurm
# Processing Record 49 of Set 14 | gryazi
# Processing Record 50 of Set 14 | tutoia
# Processing Record 1 of Set 15 | champerico
# Processing Record 2 of Set 15 | christchurch
# Processing Record 3 of Set 15 | jalu
# Processing Record 4 of Set 15 | saskylakh
# Processing Record 5 of Set 15 | praia da vitoria
# Processing Record 6 of Set 15 | sao jose da coroa grande
# Processing Record 7 of Set 15 | victoria
# Processing Record 8 of Set 15 | vagay
# Processing Record 9 of Set 15 | kholodnyy
# Processing Record 10 of Set 15 | lastoursville
# Processing Record 11 of Set 15 | maryville
# Processing Record 12 of Set 15 | sovetskaya gavan
# Processing Record 13 of Set 15 | lewisporte
# Processing Record 14 of Set 15 | ananas
# Processing Record 15 of Set 15 | tabou
# Processing Record 16 of Set 15 | moerai
# Processing Record 17 of Set 15 | dryden
# Processing Record 18 of Set 15 | matameye
# City not found. Skipping...
# Processing Record 19 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 15 | thanh hoa
# Processing Record 21 of Set 15 | bougouni
# Processing Record 22 of Set 15 | aksha
# Processing Record 23 of Set 15 | sarakhs
# Processing Record 24 of Set 15 | natal
# Processing Record 25 of Set 15 | dunedin
# Processing Record 26 of Set 15 | antofagasta
# Processing Record 27 of Set 15 | kontagora
# Processing Record 28 of Set 15 | la peca
# Processing Record 29 of Set 15 | sabha
# Processing Record 30 of Set 15 | entre rios
# Processing Record 31 of Set 15 | launceston
# Processing Record 32 of Set 15 | tombouctou
# Processing Record 33 of Set 15 | georgiyevka
# Processing Record 34 of Set 15 | burnie
# Processing Record 35 of Set 15 | guerrero negro
# Processing Record 36 of Set 15 | snasa
# Processing Record 37 of Set 15 | zemio
# Processing Record 38 of Set 15 | henties bay
# Processing Record 39 of Set 15 | lodja
# Processing Record 40 of Set 15 | belyy yar
# Processing Record 41 of Set 15 | san isidro
# Processing Record 42 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 43 of Set 15 | lac du bonnet
# Processing Record 44 of Set 15 | atikokan
# Processing Record 45 of Set 15 | gravdal
# Processing Record 46 of Set 15 | sorada
# Processing Record 47 of Set 15 | sinnamary
# Processing Record 48 of Set 15 | the valley
# Processing Record 49 of Set 15 | bud
# Processing Record 50 of Set 15 | stanislav
# Processing Record 1 of Set 16 | tukrah
# Processing Record 2 of Set 16 | ormond beach
# Processing Record 3 of Set 16 | pochutla
# Processing Record 4 of Set 16 | muzhi
# Processing Record 5 of Set 16 | arrifes
# Processing Record 6 of Set 16 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 16 | cam ranh
# Processing Record 8 of Set 16 | nome
# Processing Record 9 of Set 16 | nyurba
# Processing Record 10 of Set 16 | izazi
# Processing Record 11 of Set 16 | batemans bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# [{'lon': -70.9167, 'lat': -53.15, 'Max Temp': 44.71, 'Humidity': 76, 'Cloudiness': 0, 'Wind Speed': 12.66, 'Country': 'CL', 'Current Description': 'clear sky', 'City': 'Punta Arenas'}, {'lon': 34.7642, 'lat': 31.61, 'Max Temp': 73.4, 'Humidity': 100, 'Cloudiness': 3, 'Wind Speed': 4.18, 'Country': 'IL', 'Current Description': 'clear sky', 'City': 'Gat'}, {'lon': -115.5012, 'lat': 41.0002, 'Max Temp': 73.42, 'Humidity': 22, 'Cloudiness': 2, 'Wind Speed': 4, 'Country': 'US', 'Current Description': 'clear sky', 'City': 'Elko'}, {'lon': 102.2797, 'lat': 60.34, 'Max Temp': 31.68, 'Humidity': 81, 'Cloudiness': 89, 'Wind Speed': 2.71, 'Country': 'RU', 'Current Description': 'overcast clouds', 'City': 'Vanavara'}, {'lon': -73.3579, 'lat': 41.1415, 'Max Temp': 61.56, 'Humidity': 88, 'Cloudiness': 100, 'Wind Speed': 20.71, 'Country': 'US', 'Current Description': 'overcast clouds', 'City': 'Westport'}]

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#         lon      lat  Max Temp  Humidity  Cloudiness  Wind Speed Country  \
# 0  -70.9167 -53.1500     44.71        76           0       12.66      CL
# 1   34.7642  31.6100     73.40       100           3        4.18      IL
# 2 -115.5012  41.0002     73.42        22           2        4.00      US
# 3  102.2797  60.3400     31.68        81          89        2.71      RU
# 4  -73.3579  41.1415     61.56        88         100       20.71      US
# 5  173.7833 -35.1000     56.91        52          55       13.94      NZ
# 6  123.7167  50.5667     39.63        29           2        7.83      CN
# 7  -69.3632  77.4840      5.00        71          18        7.65      GL
# 8   88.3972  69.4865     31.21        95         100        3.98      RU
# 9  -76.4093  17.8815     83.82        85          36        7.74      JM
#
#   Current Description          City
# 0           clear sky  Punta Arenas
# 1           clear sky           Gat
# 2           clear sky          Elko
# 3     overcast clouds      Vanavara
# 4     overcast clouds      Westport
# 5       broken clouds          Kaeo
# 6           clear sky         Alihe
# 7          few clouds       Qaanaaq
# 8     overcast clouds       Talnakh
# 9    scattered clouds    Morant Bay

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['lon', 'lat', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed',
#        'Country', 'Current Description', 'City'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# First rename lat and lon columns to match sample output
city_data_df = city_data_df.rename(columns={'lon': 'Lng', 'lat': 'Lat'})
col_list = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.reindex(columns=col_list)

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     44.71        76           0
# 1           Gat      IL  31.6100   34.7642     73.40       100           3
# 2          Elko      US  41.0002 -115.5012     73.42        22           2
# 3      Vanavara      RU  60.3400  102.2797     31.68        81          89
# 4      Westport      US  41.1415  -73.3579     61.56        88         100
# 5          Kaeo      NZ -35.1000  173.7833     56.91        52          55
# 6         Alihe      CN  50.5667  123.7167     39.63        29           2
# 7       Qaanaaq      GL  77.4840  -69.3632      5.00        71          18
# 8       Talnakh      RU  69.4865   88.3972     31.21        95         100
# 9    Morant Bay      JM  17.8815  -76.4093     83.82        85          36
#
#    Wind Speed Current Description
# 0       12.66           clear sky
# 1        4.18           clear sky
# 2        4.00           clear sky
# 3        2.71     overcast clouds
# 4       20.71     overcast clouds
# 5       13.94       broken clouds
# 6        7.83           clear sky
# 7        7.65          few clouds
# 8        3.98     overcast clouds
# 9        7.74    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
file_name = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(file_name)
